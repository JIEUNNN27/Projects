# %%
pip install sklearn
# Out:
# Requirement already satisfied: sklearn in c:\users\silvi\anaconda3\envs\test\lib\site-packages (0.0.post1)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\silvi\anaconda3\envs\test\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\silvi\anaconda3\envs\test\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\silvi\anaconda3\envs\test\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\silvi\anaconda3\envs\test\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\silvi\anaconda3\envs\test\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\silvi\anaconda3\envs\test\lib\site-packages)

# %%
pip install lightgbm
# Out:
# Collecting lightgbm
#   Downloading lightgbm-3.3.5-py3-none-win_amd64.whl (1.0 MB)
#      ---------------------------------------- 0.0/1.0 MB ? eta -:--:--
#      --------------- ------------------------ 0.4/1.0 MB 12.9 MB/s eta 0:00:01
#      ---------------------------------- ----- 0.9/1.0 MB 11.2 MB/s eta 0:00:01
#      ---------------------------------------- 1.0/1.0 MB 9.3 MB/s eta 0:00:00
# Requirement already satisfied: numpy in c:\users\silvi\anaconda3\envs\test\lib\site-packages (from lightgbm) (1.24.2)
# Requirement already satisfied: scikit-learn!=0.22.0 in c:\users\silvi\anaconda3\envs\test\lib\site-packages (from lightgbm) (1.2.2)
# Requirement already satisfied: wheel in c:\users\silvi\anaconda3\envs\test\lib\site-packages (from lightgbm) (0.38.4)
# Requirement already satisfied: scipy in c:\users\silvi\anaconda3\envs\test\lib\site-packages (from lightgbm) (1.10.1)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\silvi\anaconda3\envs\test\lib\site-packages (from scikit-learn!=0.22.0->lightgbm) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\silvi\anaconda3\envs\test\lib\site-packages (from scikit-learn!=0.22.0->lightgbm) (3.1.0)
# Installing collected packages: lightgbm
# Successfully installed lightgbm-3.3.5
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\silvi\anaconda3\envs\test\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\silvi\anaconda3\envs\test\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\silvi\anaconda3\envs\test\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\silvi\anaconda3\envs\test\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\silvi\anaconda3\envs\test\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\silvi\anaconda3\envs\test\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\silvi\anaconda3\envs\test\lib\site-packages)

# %%
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split
import lightgbm as lgb
from sklearn.metrics import f1_score

# Load the training data
train_df = pd.read_csv('train.csv')

# Preprocess the text data using CountVectorizer
vectorizer = CountVectorizer(stop_words='english')
X = vectorizer.fit_transform(train_df['text'])
y = train_df['label']

# Split the data into training and validation sets
train_feature, val_feature, train_target, val_target = train_test_split(X, y, test_size=0.2)

# Convert the feature matrices to float64
train_feature = train_feature.astype('float64')
val_feature = val_feature.astype('float64')

# Train a LightGBM model
params = {
    'objective': 'multiclass',
    'num_class': 8,
    'metric': 'multi_logloss',
    'boosting_type': 'gbdt'
}

d_train = lgb.Dataset(train_feature, label=train_target)
d_val = lgb.Dataset(val_feature, label=val_target, reference=d_train)

model = lgb.train(params, d_train, valid_sets=[d_val], num_boost_round=100)

# Load the test data
test_df = pd.read_csv('test.csv')

# Preprocess the test data using the same vectorizer
test_feature = vectorizer.transform(test_df['text'])

# Convert the feature matrix to float64
test_feature = test_feature.astype('float64')

# Make predictions on the test data
y_pred = model.predict(test_feature)

# Convert the predicted probabilities to class labels
y_pred_labels = y_pred.argmax(axis=1)

# Evaluate the validation set using macro F1 score
val_pred_labels = model.predict(val_feature).argmax(axis=1)
val_f1_score = f1_score(val_target, val_pred_labels, average='macro')

# Print the validation F1 score
print("Validation F1 score:", val_f1_score)

# Save the submission file
submission_df = pd.DataFrame({'id': test_df['id'], 'label': y_pred_labels})
submission_df.to_csv('submission.csv', index=False)
# Out:
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.651856 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 131419
# [LightGBM] [Info] Number of data points in the train set: 37919, number of used features: 22503
# [LightGBM] [Info] Start training from score -1.212598
# [LightGBM] [Info] Start training from score -1.464686
# [LightGBM] [Info] Start training from score -1.617620
# [LightGBM] [Info] Start training from score -1.664571
# [LightGBM] [Info] Start training from score -2.958943
# [LightGBM] [Info] Start training from score -3.827824
# [LightGBM] [Info] Start training from score -5.140530
# [LightGBM] [Info] Start training from score -5.449457
# [1]	valid_0's multi_logloss: 1.33551
# [2]	valid_0's multi_logloss: 1.18755
# [3]	valid_0's multi_logloss: 1.07303
# [4]	valid_0's multi_logloss: 0.983041
# [5]	valid_0's multi_logloss: 0.910062
# [6]	valid_0's multi_logloss: 0.848431
# [7]	valid_0's multi_logloss: 0.796606
# [8]	valid_0's multi_logloss: 0.752445
# [9]	valid_0's multi_logloss: 0.714457
# [10]	valid_0's multi_logloss: 0.6802
# [11]	valid_0's multi_logloss: 0.650219
# [12]	valid_0's multi_logloss: 0.62327
# [13]	valid_0's multi_logloss: 0.600033
# [14]	valid_0's multi_logloss: 0.578889
# [15]	valid_0's multi_logloss: 0.560148
# [16]	valid_0's multi_logloss: 0.542697
# [17]	valid_0's multi_logloss: 0.526635
# [18]	valid_0's multi_logloss: 0.510786
# [19]	valid_0's multi_logloss: 0.497308
# [20]	valid_0's multi_logloss: 0.484984
# [21]	valid_0's multi_logloss: 0.472902
# [22]	valid_0's multi_logloss: 0.462847
# [23]	valid_0's multi_logloss: 0.452836
# [24]	valid_0's multi_logloss: 0.443902
# [25]	valid_0's multi_logloss: 0.435354
# [26]	valid_0's multi_logloss: 0.427248
# [27]	valid_0's multi_logloss: 0.420098
# [28]	valid_0's multi_logloss: 0.413446
# [29]	valid_0's multi_logloss: 0.406891
# [30]	valid_0's multi_logloss: 0.400994
# [31]	valid_0's multi_logloss: 0.395443
# [32]	valid_0's multi_logloss: 0.39019
# [33]	valid_0's multi_logloss: 0.38571
# [34]	valid_0's multi_logloss: 0.381144
# [35]	valid_0's multi_logloss: 0.377193
# [36]	valid_0's multi_logloss: 0.373302
# [37]	valid_0's multi_logloss: 0.369252
# [38]	valid_0's multi_logloss: 0.36578
# [39]	valid_0's multi_logloss: 0.36236
# [40]	valid_0's multi_logloss: 0.359022
# [41]	valid_0's multi_logloss: 0.355929
# [42]	valid_0's multi_logloss: 0.35315
# [43]	valid_0's multi_logloss: 0.350352
# [44]	valid_0's multi_logloss: 0.34745
# [45]	valid_0's multi_logloss: 0.344838
# [46]	valid_0's multi_logloss: 0.342358
# [47]	valid_0's multi_logloss: 0.339923
# [48]	valid_0's multi_logloss: 0.337917
# [49]	valid_0's multi_logloss: 0.335792
# [50]	valid_0's multi_logloss: 0.334074
# [51]	valid_0's multi_logloss: 0.332083
# [52]	valid_0's multi_logloss: 0.330361
# [53]	valid_0's multi_logloss: 0.328371
# [54]	valid_0's multi_logloss: 0.326686
# [55]	valid_0's multi_logloss: 0.325198
# [56]	valid_0's multi_logloss: 0.323677
# [57]	valid_0's multi_logloss: 0.322315
# [58]	valid_0's multi_logloss: 0.320589
# [59]	valid_0's multi_logloss: 0.319314
# [60]	valid_0's multi_logloss: 0.317825
# [61]	valid_0's multi_logloss: 0.316527
# [62]	valid_0's multi_logloss: 0.315287
# [63]	valid_0's multi_logloss: 0.314201
# [64]	valid_0's multi_logloss: 0.312863
# [65]	valid_0's multi_logloss: 0.311567
# [66]	valid_0's multi_logloss: 0.310363
# [67]	valid_0's multi_logloss: 0.309479
# [68]	valid_0's multi_logloss: 0.308563
# [69]	valid_0's multi_logloss: 0.30772
# [70]	valid_0's multi_logloss: 0.30671
# [71]	valid_0's multi_logloss: 0.305946
# [72]	valid_0's multi_logloss: 0.305233
# [73]	valid_0's multi_logloss: 0.304396
# [74]	valid_0's multi_logloss: 0.303552
# [75]	valid_0's multi_logloss: 0.302522
# [76]	valid_0's multi_logloss: 0.301517
# [77]	valid_0's multi_logloss: 0.300838
# [78]	valid_0's multi_logloss: 0.300127
# [79]	valid_0's multi_logloss: 0.299287
# [80]	valid_0's multi_logloss: 0.298569
# [81]	valid_0's multi_logloss: 0.297897
# [82]	valid_0's multi_logloss: 0.297141
# [83]	valid_0's multi_logloss: 0.29652
# [84]	valid_0's multi_logloss: 0.29586
# [85]	valid_0's multi_logloss: 0.295243
# [86]	valid_0's multi_logloss: 0.2947
# [87]	valid_0's multi_logloss: 0.294023
# [88]	valid_0's multi_logloss: 0.293598
# [89]	valid_0's multi_logloss: 0.292926
# [90]	valid_0's multi_logloss: 0.292423
# [91]	valid_0's multi_logloss: 0.291942
# [92]	valid_0's multi_logloss: 0.291385
# [93]	valid_0's multi_logloss: 0.290824
# [94]	valid_0's multi_logloss: 0.290405
# [95]	valid_0's multi_logloss: 0.289998
# [96]	valid_0's multi_logloss: 0.289487
# [97]	valid_0's multi_logloss: 0.288775
# [98]	valid_0's multi_logloss: 0.288344
# [99]	valid_0's multi_logloss: 0.287976
# [100]	valid_0's multi_logloss: 0.287596
# Validation F1 score: 0.8459743655028871
